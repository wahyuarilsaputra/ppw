# %% [markdown]
# # Tugas 1 PPW : Crawling Data PTA Trunojoyo

# %% [markdown]
# ## Install Requirement

# %%
# !pip install requests
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %% [markdown]
# ## Crawling data PTA

# %%
header={
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'
}
#Cari Berdasarkan
pencarian = 'Prodi'
kode = 10
pta_list = []
for halaman in range(1,30):
  if pencarian == 'Fakultas':
    url = f"https://pta.trunojoyo.ac.id/c_search/byfac/{kode}/{str(halaman+1)}"
  elif pencarian == 'Prodi':
    url = f"https://pta.trunojoyo.ac.id/c_search/byprod/{kode}/{str(halaman+1)}"
  req = requests.get(url)
  soup = BeautifulSoup(req.text, 'lxml')
  prodi = soup.find('h2').text.replace('Journal','')
  list_ = soup.find('div', {'id':'content_journal'})

  for pta in list_.findAll('li',{'data-cat':'#luxury'}):
    span_elements = pta.find_all('span')
    Nama = span_elements[0].get_text(strip=True).replace('Penulis : ', '')
    pembimbing1 = span_elements[1].get_text(strip=True).replace('Dosen Pembimbing I : ', '')
    pembimbing2 = span_elements[2].get_text(strip=True).replace('Dosen Pembimbing II :', '')
    link = pta.find('a', 'gray button')['href']
    req = requests.get(link)
    soup2 = BeautifulSoup(req.text, 'lxml')
    judul = pta.a.text.strip('\n').replace('\r','').replace('\n','')
    abstrak = soup2.find('p', {'align':'justify'}).text.replace('ABSTRAK','').replace('\r','').replace('\n','').replace('\t','')

    pta_list.append([judul,Nama,pembimbing1,pembimbing2,abstrak,prodi])

# %%
frame_pta = pd.DataFrame(pta_list, columns=['Judul','Nama Penulis','Pembimbing I','Pembimbing II','Abstrak',pencarian])
frame_pta
# Out:
#                                                  Judul           Nama Penulis  \
# 0    Gerak Pekerja Pada Game Real Time Strategy Men...    Adi Chandra Laksono
# 1    RANCANG BANGUN GAME PERAWATAN SAPI KARAPAN MEN...             NURRACHMAT
# 2    EKSTRAKSI FITUR BERBASIS TWO DIMENSIONAL LINEA...  Muhammad Choirur Rozi
# 3    IMPLEMENTASI  ALGORITMA PRIM  DAN DEPTH FIRST ...        M Khoiril Anwar
# 4    Perancangan Sistem Informasi Badan Kepegawaian...         MALIKUL HAMZAH
# ..                                                 ...                    ...
# 140  SIMULASI LAMPU LALU LINTAS PADA SEBUAH PERSIMP...       Ahmad Afwan Arin
# 141  Implementasi Jena dan SPARQL untuk Optimalisas...    Yanuari Dwi Prianto
# 142  SISTEM PENDUKUNG KEPUTUSAN REKOMENDASI JURUSAN...   LEILY AULA RAHMAWATI
# 143  PENGENALAN WAJAH MENGGUNAKAN EKSTRAKSI FITUR D...  Maulidiah Purnamasari
# 144  IMPLEMENTASI ALGORITMA ENKRIPSI AES UNTUK APLI...       Awang Maristyono
#
#                             Pembimbing I                        Pembimbing II  \
# 0           Kurniawan Eka P, S.Kom., Msc        Arik Kurniawati, S.Kom., M.T.
# 1          Arik Kurniawati, S.Kom., M.T.  Kurniawan Eka Permana, S.Kom., MSc.
# 2            Dr. Arif Muntasa, S.Si.,M.T        Fitri Damayanti, S.Kom.,M.kom
# 3         Cucun Very Angkoso, S.T., M.T.        Arik Kurniawati S. Kom., M.T.
# 4    Moch. Kautsar Sophan, S.Kom., M.MT.  Yeni Kustiyaningsih, S.Kom., M.Kom.
# ..                                   ...                                  ...
# 140  Dr. Indah Agustien S, S.Kom, M.Kom.    Bain Khusnul Khotimah, ST.,M.Kom.
# 141         Fika Hastarita R, ST., M.Eng                Iwan Santosa, ST., MT
# 142  FIKA HASTARITA RACHMAN,S.T., M.Eng.  BAIN KHUSNUL KHOTIMAH, S.T., M.Kom.
# 143      Rima Tri Wahyuningrum,S.T.,M.T.        Fitri Damayanti,S.Kom.,M.Kom.
# 144         Cucun Very Angkoso, ST., M.T   Moch. Kautsar Sophan, S.Kom., M.MT
#
#                                                Abstrak  \
# 0    Gerak pekerja ada pada game yang memiliki genr...
# 1    Perkembangan game yang semakin pesat, memberik...
# 2    Sistem pengenalan wajah adalah suatu sistem un...
# 3    Teknologi mobile game beroperating system open...
# 4    Kantor Badan Kepegawaian kota Bangkalan adalah...
# ..                                                 ...
# 140  Kemacetan lalu lintas merupakan masalah yang h...
# 141  Search engine saat ini menggunakan mekanisme t...
# 142  Beragam jurusan yang ada pada SMKN 1 Buduran S...
# 143  Pada umumnya kemajuan teknologi untuk mendetek...
# 144  Pengiriman informasi Short Message Service (SM...
#
#                            Prodi
# 0     Jurusan Teknik Informatika
# 1     Jurusan Teknik Informatika
# 2     Jurusan Teknik Informatika
# 3     Jurusan Teknik Informatika
# 4     Jurusan Teknik Informatika
# ..                           ...
# 140   Jurusan Teknik Informatika
# 141   Jurusan Teknik Informatika
# 142   Jurusan Teknik Informatika
# 143   Jurusan Teknik Informatika
# 144   Jurusan Teknik Informatika
#
# [145 rows x 6 columns]

# %% [markdown]
# ## Import Data Frame ke Csv

# %%
frame_pta.to_csv('DataPTAInformatika.csv',sep=',',index=False)
